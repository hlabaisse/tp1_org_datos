# %% [markdown]
# # TP1: Organizacion de datos

# %% [markdown]
# ## I / Manipulation and presentation of the data

# %%
### Import the librairies

import pandas as pd
import matplotlib.pyplot as plt

# %%
### Read the csv
df = pd.read_csv(r'C:/Users/hugol/Downloads/tp1/events.csv', dtype = {'sku': str})
df['timestamp'] = df['timestamp'].astype('datetime64[ns]')

# %%
### Show how the data is stored

df.head()
# Out:
#             timestamp            event    person                        url  \
# 0 2018-05-31 23:38:05  ad campaign hit  0004b0a2  /comprar/iphone/iphone-5s
# 1 2018-05-31 23:38:05     visited site  0004b0a2                        NaN
# 2 2018-05-31 23:38:09   viewed product  0004b0a2                        NaN
# 3 2018-05-31 23:38:40         checkout  0004b0a2                        NaN
# 4 2018-05-29 13:29:25   viewed product  0006a21a                        NaN
#
#        sku              model condition storage           color skus  \
# 0      NaN                NaN       NaN     NaN             NaN  NaN
# 1      NaN                NaN       NaN     NaN             NaN  NaN
# 2   2694.0          iPhone 5s       Bom    32GB  Cinza espacial  NaN
# 3   2694.0          iPhone 5s       Bom    32GB  Cinza espacial  NaN
# 4  15338.0  Samsung Galaxy S8       Bom    64GB         Dourado  NaN
#
#          ...        search_engine channel new_vs_returning        city  \
# 0        ...                  NaN     NaN              NaN         NaN
# 1        ...                  NaN    Paid              New  Camaragibe
# 2        ...                  NaN     NaN              NaN         NaN
# 3        ...                  NaN     NaN              NaN         NaN
# 4        ...                  NaN     NaN              NaN         NaN
#
#        region country device_type screen_resolution operating_system_version  \
# 0         NaN     NaN         NaN               NaN                      NaN
# 1  Pernambuco  Brazil  Smartphone           360x640                Android 6
# 2         NaN     NaN         NaN               NaN                      NaN
# 3         NaN     NaN         NaN               NaN                      NaN
# 4         NaN     NaN         NaN               NaN                      NaN
#
#     browser_version
# 0               NaN
# 1  Chrome Mobile 39
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 23 columns]

# %%
### Resume of the datas

df.describe()
# Out:
#                   timestamp           event    person    url     sku  \
# count               1011288         1011288   1011288  82756  563838
# unique               793805              11     27624    227    3574
# top     2018-05-15 15:56:06  viewed product  71492f2b      /  2830.0
# freq                     11          528931      2771  28323    4282
# first   2018-01-01 07:32:26             NaN       NaN    NaN     NaN
# last    2018-06-15 23:59:31             NaN       NaN    NaN     NaN
#
#            model condition storage   color  \
# count     564284    563836  563836  563836
# unique       202         5       8      63
# top     iPhone 6       Bom    16GB   Preto
# freq       50916    243014  190833  132960
# first        NaN       NaN     NaN     NaN
# last         NaN       NaN     NaN     NaN
#
#                                                      skus       ...        \
# count                                              221699       ...
# unique                                              35310       ...
# top     2820,6706,6720,2750,6649,7251,6663,12604,7224,...       ...
# freq                                                  594       ...
# first                                                 NaN       ...
# last                                                  NaN       ...
#
#        search_engine channel new_vs_returning     city     region country  \
# count          50957   87378            87378    87378      87378   87378
# unique             4       7                2     1939         93      46
# top           Google    Paid        Returning  Unknown  Sao Paulo  Brazil
# freq           50240   44193            60480    15819      24996   84308
# first            NaN     NaN              NaN      NaN        NaN     NaN
# last             NaN     NaN              NaN      NaN        NaN     NaN
#
#        device_type screen_resolution operating_system_version browser_version
# count        87378             87378                    87378           87378
# unique           4               282                      121             343
# top     Smartphone           360x640               Windows 7      Chrome 66.0
# freq         44239             30009                    19675           22611
# first          NaN               NaN                      NaN             NaN
# last           NaN               NaN                      NaN             NaN
#
# [6 rows x 23 columns]

# %%
### Show the different types of events

df['event'].unique()
# Out:
# array(['ad campaign hit', 'visited site', 'viewed product', 'checkout',
#        'generic listing', 'search engine hit', 'brand listing',
#        'searched products', 'conversion', 'staticpage', 'lead'],
#       dtype=object)

# %%
df.groupby('event').count()
# Out:
#                    timestamp  person    url     sku   model  condition  \
# event
# ad campaign hit        82827   82827  82756       0       0          0
# brand listing          98635   98635      0       0       0          0
# checkout               33735   33735      0   33735   33733      33733
# conversion              1172    1172      0    1172    1172       1172
# generic listing        67534   67534      0       0       0          0
# lead                     448     448      0       0     448          0
# search engine hit      50957   50957      0       0       0          0
# searched products      56073   56073      0       0       0          0
# staticpage              3598    3598      0       0       0          0
# viewed product        528931  528931      0  528931  528931     528931
# visited site           87378   87378      0       0       0          0
#
#                    storage   color   skus  search_term       ...         \
# event                                                        ...
# ad campaign hit          0       0      0            0       ...
# brand listing            0       0  98324            0       ...
# checkout             33733   33733      0            0       ...
# conversion            1172    1172      0            0       ...
# generic listing          0       0  67421            0       ...
# lead                     0       0      0            0       ...
# search engine hit        0       0      0            0       ...
# searched products        0       0  55954        48967       ...
# staticpage               0       0      0            0       ...
# viewed product      528931  528931      0            0       ...
# visited site             0       0      0            0       ...
#
#                    search_engine  channel  new_vs_returning   city  region  \
# event
# ad campaign hit                0        0                 0      0       0
# brand listing                  0        0                 0      0       0
# checkout                       0        0                 0      0       0
# conversion                     0        0                 0      0       0
# generic listing                0        0                 0      0       0
# lead                           0        0                 0      0       0
# search engine hit          50957        0                 0      0       0
# searched products              0        0                 0      0       0
# staticpage                     0        0                 0      0       0
# viewed product                 0        0                 0      0       0
# visited site                   0    87378             87378  87378   87378
#
#                    country  device_type  screen_resolution  \
# event
# ad campaign hit          0            0                  0
# brand listing            0            0                  0
# checkout                 0            0                  0
# conversion               0            0                  0
# generic listing          0            0                  0
# lead                     0            0                  0
# search engine hit        0            0                  0
# searched products        0            0                  0
# staticpage               0            0                  0
# viewed product           0            0                  0
# visited site         87378        87378              87378
#
#                    operating_system_version  browser_version
# event
# ad campaign hit                           0                0
# brand listing                             0                0
# checkout                                  0                0
# conversion                                0                0
# generic listing                           0                0
# lead                                      0                0
# search engine hit                         0                0
# searched products                         0                0
# staticpage                                0                0
# viewed product                            0                0
# visited site                          87378            87378
#
# [11 rows x 22 columns]

# %% [markdown]
# ## Analisis of the conversion event

# %% [markdown]
# ### Determine the model the most sold

# %%
### Create a dataframe for the event conversion only

df_conversion = df[df['event'] == 'conversion']

# %%
df_conversion.groupby('model').size().sort_values(ascending=False)
# Out:
# model
# Samsung Galaxy J5                    88
# iPhone 5s                            84
# iPhone 6                             71
# Motorola Moto G4 Plus        30     30     0            0       ...
# Motorola Moto G3 4G          30     30     0            0       ...
# Samsung Galaxy J7            28     28     0            0       ...
# Samsung Galaxy A5            27     27     0            0       ...
#
#                         search_engine  channel  new_vs_returning  city  \
# model
# Samsung Galaxy J5                   0        0                 0     0
# iPhone 5s                           0        0                 0     0
# iPhone 6                            0        0                 0     0
# Samsung Galaxy S6 Flat              0        0                 0     0
# iPhone 6S                           0        0                 0     0
# iPhone 5c                           0        0                 0     0
# Motorola Moto G4 Plus               0        0                 0     0
# Motorola Moto G3 4G                 0        0                 0     0
# Samsung Galaxy J7                   0        0                 0     0
# Samsung Galaxy A5                   0        0                 0     0
#
#                         region  country  device_type  screen_resolution  \
# model
# Samsung Galaxy J5            0        0            0                  0
# iPhone 5s                    0        0            0                  0
# iPhone 6                     0        0            0                  0
# Samsung Galaxy S6 Flat       0        0            0                  0
# iPhone 6S                    0        0            0                  0
# iPhone 5c                    0        0            0                  0
# Motorola Moto G4 Plus        0        0            0                  0
# Motorola Moto G3 4G          0        0            0                  0
# Samsung Galaxy J7            0        0            0                  0
# Samsung Galaxy A5            0        0            0                  0
#
#                         operating_system_version  browser_version
# model
# Samsung Galaxy J5                              0                0
# iPhone 5s                                      0                0
# iPhone 6                                       0                0
# Samsung Galaxy S6 Flat                         0                0
# iPhone 6S                                      0                0
# iPhone 5c                                      0                0
# Motorola Moto G4 Plus                          0                0
# Motorola Moto G3 4G                            0                0
# Samsung Galaxy J7                              0                0
# Samsung Galaxy A5                              0                0
#
# [10 rows x 22 columns]

# %% [markdown]
# <div class="alert alert-warning"> Three models are far more represented than the others: Samsung Galaxy J5, iphone 5, iphone 6 </div>

# %% [markdown]
# <div class="alert alert-info"> How to print it ? Only the 5th first ? The 3 first in term of percentage ?
# </div>

# %% [markdown]
# visite + si iphone ou autre: nombre visite moyen
# si touché par une campagne pub

# %% [markdown]
# ### Determine the repartition of the brand sold

# %%
### Total of conversions

number_conversions = len(df_conversion.groupby('model').count().sum())

# %%
### Get the number of iPhone, Samsung and Motorola sold

df_conversion_iPhone = df_conversion[df_conversion['model'].str.contains("iPhone")==True]
number_iphone_conversion = len(df_conversion_iPhone)

df_conversion_samsung = df_conversion[df_conversion['model'].str.contains("Samsung")==True]
number_samsung_conversion = len(df_conversion_samsung)

df_conversion_motorola = df_conversion[df_conversion['model'].str.contains("Motorola")==True]
number_motorola_conversion = len(df_conversion_motorola)

# %%
print("Number of iphone sold:" , number_iphone_conversion)
print("Percentage of iPhone sold:" , number_iphone_conversion/number_conversions)

print("Number of samsung sold", number_samsung_conversion)
print("Percentage of Samsung sold", number_samsung_conversion/number_conversions)

print("Number of motorola sold", number_motorola_conversion)
print("Percentage of motorola sold", number_motorola_conversion/number_conversions)
# Out:
# Number of iphone sold: 323
# Percentage of iPhone sold: 14.681818181818182
# Number of samsung sold 641
# Percentage of Samsung sold 29.136363636363637
# Number of motorola sold 149
# Percentage of motorola sold 6.7727272727272725

# %% [markdown]
#  'Samsung Galaxy S4 i9515' 'Motorola Moto G2 4G Dual' 'Motorola Moto Z'
#  'Samsung Galaxy S6 Edge Plus' 'Samsung Galaxy S4 i9505'
#  'Asus Zenfone 3 Max 16 GB' 'Samsung Galaxy A9 Pro 2016'
#  'Samsung Galaxy Gran Neo Duos' 'iPhone 8'
#  'Samsung Galaxy Note 3 Neo Duos' 'Samsung Galaxy Note 4'
#  'Lenovo Vibe A7010 Dual Chip' 'Samsung Galaxy Gran 2 Duos TV'
#  'Samsung Gear S2' 'Samsung Galaxy S4 Mini Duos' 'Sony Xperia Z3 Dual'
#  'Motorola Moto G3 HDTV' 'Samsung Galaxy Win 2 Duos TV'
#  'Motorola Moto Z2 Play' 'Asus Zenfone 5' 'Samsung Galaxy A3 2016'
#  'LG L Prime D337' 'Sony Xperia Z3 Plus' 'Samsung Galaxy Note 3'
#  'Motorola Moto G5S Plus' 'Samsung Galaxy E5 4G Duos']

# %% [markdown]
# ### Determine the condition repartition on the phones sold

# %%
##Repartition of the condition of the phones sold
df_conversion.groupby('condition').count().sort_values(by='timestamp', ascending=False)
# Out:
#                     timestamp  event  person  url  sku  model  storage  color  \
# condition
# Bom                       538    538     538    0  538    538      538    538
# Muito Bom                 352    352     352    0  352    352      352    352
# Excelente                 258    258     258    0  258    258      258    258
# Bom - Sem Touch ID         22     22      22    0   22     22       22     22
# Novo                        2      2       2    0    2      2        2      2
#
#                     skus  search_term       ...         search_engine  \
# condition                                   ...
# Bom                    0            0       ...                     0
# Muito Bom              0            0       ...                     0
# Excelente              0            0       ...                     0
# Bom - Sem Touch ID     0            0       ...                     0
# Novo                   0            0       ...                     0
#
#                     channel  new_vs_returning  city  region  country  \
# condition
# Bom                       0                 0     0       0        0
# Muito Bom                 0                 0     0       0        0
# Excelente                 0                 0     0       0        0
# Bom - Sem Touch ID        0                 0     0       0        0
# Novo                      0                 0     0       0        0
#
#                     device_type  screen_resolution  operating_system_version  \
# condition
# Bom                           0                  0                         0
# Muito Bom                     0                  0                         0
# Excelente                     0                  0                         0
# Bom - Sem Touch ID            0                  0                         0
# Novo                          0                  0                         0
#
#                     browser_version
# condition
# Bom                               0
# Muito Bom                         0
# Excelente                         0
# Bom - Sem Touch ID                0
# Novo                              0
#
# [5 rows x 22 columns]

# %% [markdown]
# <div class = 'div alert alert-warning'> People almost never bought new smartphones. They prefer largely the smartphone in good condition but also excellent and half good. It is a second-handed market. </div>

# %% [markdown]
# ### Determine the storage repartition on the phones sold

# %%
df_conversion.groupby('storage').count().sort_values(by='timestamp', ascending=False)
# Out:
#          timestamp  event  person  url  sku  model  condition  color  skus  \
# storage
# 16GB           552    552     552    0  552    552        552    552     0
# 32GB           265    265     265    0  265    265        265    265     0
# 8GB            205    205     205    0  205    205        205    205     0
# 64GB           102    102     102    0  102    102        102    102     0
# 128GB           27     27      27    0   27     27         27     27     0
# 4GB             17     17      17    0   17     17         17     17     0
# 512MB            3      3       3    0    3      3          3      3     0
# 256GB            1      1       1    0    1      1          1      1     0
#
#          search_term       ...         search_engine  channel  \
# storage                    ...
# 16GB               0       ...                     0        0
# 32GB               0       ...                     0        0
# 8GB                0       ...                     0        0
# 64GB               0       ...                     0        0
# 128GB              0       ...                     0        0
# 4GB                0       ...                     0        0
# 512MB              0       ...                     0        0
# 256GB              0       ...                     0        0
#
#          new_vs_returning  city  region  country  device_type  \
# storage
# 16GB                    0     0       0        0            0
# 32GB                    0     0       0        0            0
# 8GB                     0     0       0        0            0
# 64GB                    0     0       0        0            0
# 128GB                   0     0       0        0            0
# 4GB                     0     0       0        0            0
# 512MB                   0     0       0        0            0
# 256GB                   0     0       0        0            0
#
#          screen_resolution  operating_system_version  browser_version
# storage
# 16GB                     0                         0                0
# 32GB                     0                         0                0
# 8GB                      0                         0                0
# 64GB                     0                         0                0
# 128GB                    0                         0                0
# 4GB                      0                         0                0
# 512MB                    0                         0                0
# 256GB                    0                         0                0
#
# [8 rows x 22 columns]

# %% [markdown]
# <div class="alert alert-info"> Show it with a bar plot ? </div>

# %% [markdown]
# <div class="alert alert-warning"> Most phones sold are 8, 16, 32 GB. 64 and 128 is a bit too much and the others are definitely too low. </div>

# %% [markdown]
# ### Determine the color repartition on the phones sold

# %%
df_conversion.groupby('color').count().sort_values(by ='timestamp', ascending=False).head(5)
# Out:
#                 timestamp  event  person  url  sku  model  condition  storage  \
# color
# Preto                 368    368     368    0  368    368        368      368
# Dourado               269    269     269    0  269    269        269      269
# Branco                216    216     216    0  216    216        216      216
# Cinza espacial         89     89      89    0   89     89         89       89
# Prateado               51     51      51    0   51     51         51       51
#
#                 skus  search_term       ...         search_engine  channel  \
# color                                   ...
# Preto              0            0       ...                     0        0
# Dourado            0            0       ...                     0        0
# Branco             0            0       ...                     0        0
# Cinza espacial     0            0       ...                     0        0
# Prateado           0            0       ...                     0        0
#
#                 new_vs_returning  city  region  country  device_type  \
# color
# Preto                          0     0       0        0            0
# Dourado                        0     0       0        0            0
# Branco                         0     0       0        0            0
# Cinza espacial                 0     0       0        0            0
# Prateado                       0     0       0        0            0
#
#                 screen_resolution  operating_system_version  browser_version
# color
# Preto                           0                         0                0
# Dourado                         0                         0                0
# Branco                          0                         0                0
# Cinza espacial                  0                         0                0
# Prateado                        0                         0                0
#
# [5 rows x 22 columns]

# %% [markdown]
# <div class = 'alert alert-warning'> Concentrate the sells (and advertising ?) on Preto, Dourado, Branco. </div>

# %% [markdown]
# ### Print the repartition of the conversion over the date

# %%
### Sort the data base over the timestamp
df_conversion2 = df_conversion.sort_values(by='timestamp')

# %%
### Evolution of the sales during the half-year, we can do with different model of phones or with different types of event

plt.plot(df_conversion2['timestamp'], [i for i in range(len(df_conversion2['timestamp']))])
plt.show()

# %% [markdown]
# ## Linear regression to predict the future sales of the year

# %% [markdown]
# <div class = 'alert alert-info'> Still in progress, it does not work </div>

# %%
### Linear regression to predict the future sell for the year 2018

### Import the libraries
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score


# Use only one feature
#diabetes_X = diabetes.data[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = df_conversion['timestamp'][:-20]
diabetes_X_test = df_conversion['timestamp'][-20:]

# Split the targets into training/testing sets
diabetes_y_train = [i for i in range(len(df_conversion['timestamp']))][:-20]
diabetes_y_test = [i for i in range(len(df_conversion['timestamp']))][-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-7df7e6190ceb> in <module>()
#      22
#      23 # Train the model using the training sets
# ---> 24 regr.fit(diabetes_X_train, diabetes_y_train)
#      25
#      26 # Make predictions using the testing set
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     439                     "Reshape your data either using array.reshape(-1, 1) if "
#     440                     "your data has a single feature or array.reshape(1, -1) "
# --> 441                     "if it contains a single sample.".format(array))
#     442             array = np.atleast_2d(array)
#     443             # To ensure that array flags are maintained
#
# ValueError: Expected 2D array, got 1D array instead:
# array=['2018-03-20T17:46:12.000000000' '2018-04-26T22:28:53.000000000'
#  '2018-06-10T14:37:50.000000000' ... '2018-03-13T11:59:38.000000000'
#  '2018-01-30T22:44:19.000000000' '2018-01-31T08:25:24.000000000'].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
import scipy.stats

scipy.stats.linregress(df_conversion['timestamp'], [i for i in range(len(df_conversion['timestamp']))])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-297836b1dbde> in <module>()
#       1 import scipy.stats
#       2
# ----> 3 scipy.stats.linregress(df_conversion['timestamp'], [i for i in range(len(df_conversion['timestamp']))])
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#      87
#      88     n = len(x)
# ---> 89     xmean = np.mean(x, None)
#      90     ymean = np.mean(y, None)
#      91
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2955
#    2956     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2957                           out=out, **kwargs)
#    2958
#    2959
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# TypeError: ufunc add cannot use operands with types dtype('<M8[ns]') and dtype('<M8[ns]')

# %%
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt

X = np.random.rand(100)
Y = X + np.random.rand(100)*0.1

results = sm.OLS(Y,sm.add_constant(X)).fit()


plt.scatter(X,Y)

X_plot = np.linspace(0,1,100)
plt.plot(X_plot, X_plot*results.params[0] + results.params[1])

plt.show()

# %%
type(df_conversion['timestamp'])
# Out:
# pandas.core.series.Series

# %%
date1 =df_conversion3['timestamp'].dt.date()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-6202c18ab1ae> in <module>()
# ----> 1 date1 =df_conversion3['timestamp'].dt.date()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4366         if (name in self._internal_names_set or name in self._metadata or
#    4367                 name in self._accessors):
# -> 4368             return object.__getattribute__(self, name)
#    4369         else:
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     130             # we're accessing the attribute of the class, i.e., Dataset.geo
#     131             return self._accessor
# --> 132         accessor_obj = self._accessor(obj)
#     133         # Replace the property with the accessor object. Inspired by:
#     134         # http://www.pydanny.com/cached-property.html
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\accessors.py in __new__(cls, data)
#     323             pass  # we raise an attribute error anyway
#     324
# --> 325         raise AttributeError("Can only use .dt accessor with datetimelike "
#     326                              "values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
df_conversion3 = df[df['event'] == 'conversion']

# %%
date2 = date1.tolist()

# %% [markdown]
# ## Analyse the people who buy product

# %%
df_person = df['person']

# %%
df_person1 = df[df['person']==df_person.iloc[14]]

# %%
df_person1
# Out:
#              timestamp              event    person  url      sku  \
# 8  2018-04-09 20:12:31    generic listing  000a54b2  NaN      NaN
# 9  2018-04-09 20:12:31       visited site  000a54b2  NaN      NaN
# 10 2018-04-09 20:12:31  search engine hit  000a54b2  NaN      NaN
# 11 2018-04-09 20:12:31    ad campaign hit  000a54b2    /      NaN
# 12 2018-04-09 20:12:53      brand listing  000a54b2  NaN      NaN
# 13 2018-04-09 20:13:14     viewed product  000a54b2  NaN  12661.0
# 14 2018-04-09 20:13:20      brand listing  000a54b2  NaN      NaN
# 15 2018-05-24 11:21:07    ad campaign hit  000a54b2    /      NaN
# 16 2018-05-24 11:21:07       visited site  000a54b2  NaN      NaN
# 17 2018-05-24 11:21:07  search engine hit  000a54b2  NaN      NaN
# 18 2018-05-24 11:21:08    generic listing  000a54b2  NaN      NaN
# 19 2018-05-24 11:26:34    generic listing  000a54b2  NaN      NaN
# 20 2018-05-24 11:26:53      brand listing  000a54b2  NaN      NaN
# 21 2018-05-24 11:26:56    generic listing  000a54b2  NaN      NaN
# 22 2018-05-24 11:27:47     viewed product  000a54b2  NaN  10254.0
# 23 2018-05-24 11:27:50    generic listing  000a54b2  NaN      NaN
# 24 2018-05-24 11:28:10      brand listing  000a54b2  NaN      NaN
# 25 2018-05-24 11:28:36      brand listing  000a54b2  NaN      NaN
# 26 2018-05-24 11:28:59     viewed product  000a54b2  NaN   6581.0
# 27 2018-05-24 11:29:06     viewed product  000a54b2  NaN   6579.0
# 28 2018-05-24 11:29:14     viewed product  000a54b2  NaN   6580.0
# 29 2018-05-24 11:29:16     viewed product  000a54b2  NaN   6581.0
# 30 2018-05-24 11:29:19     viewed product  000a54b2  NaN   6580.0
# 31 2018-05-24 11:29:23     viewed product  000a54b2  NaN   8965.0
# 32 2018-05-24 11:30:07     viewed product  000a54b2  NaN   6580.0
# 33 2018-05-24 11:30:09     viewed product  000a54b2  NaN   6581.0
# 34 2018-05-24 11:30:11     viewed product  000a54b2  NaN   6580.0
# 35 2018-05-24 11:30:15     viewed product  000a54b2  NaN   6579.0
# 36 2018-05-24 11:30:16     viewed product  000a54b2  NaN   6581.0
# 37 2018-05-24 11:30:18     viewed product  000a54b2  NaN   6580.0
# 38 2018-05-24 11:30:22     viewed product  000a54b2  NaN   6874.0
# 39 2018-05-24 11:30:24     viewed product  000a54b2  NaN   6930.0
# 40 2018-05-24 11:30:26     viewed product  000a54b2  NaN   6902.0
# 41 2018-05-24 11:30:29     viewed product  000a54b2  NaN   6916.0
# 42 2018-05-24 11:32:39      brand listing  000a54b2  NaN      NaN
# 43 2018-05-24 11:33:23     viewed product  000a54b2  NaN  12660.0
# 44 2018-05-24 11:34:32           checkout  000a54b2  NaN  12660.0
#
#                    model  condition storage           color  \
# 8                    NaN        NaN     NaN             NaN
# 9                    NaN        NaN     NaN             NaN
# 10                   NaN        NaN     NaN             NaN
# 11                   NaN        NaN     NaN             NaN
# 12                   NaN        NaN     NaN             NaN
# 13  Motorola Moto Z Play  Muito Bom    32GB           Preto
# 14                   NaN        NaN     NaN             NaN
# 15                   NaN        NaN     NaN             NaN
# 16                   NaN        NaN     NaN             NaN
# 17                   NaN        NaN     NaN             NaN
# 18                   NaN        NaN     NaN             NaN
# 19                   NaN        NaN     NaN             NaN
# 20                   NaN        NaN     NaN             NaN
# 21                   NaN        NaN     NaN             NaN
# 22         iPhone 7 Plus  Excelente   256GB         Dourado
# 23                   NaN        NaN     NaN             NaN
# 24                   NaN        NaN     NaN             NaN
# 25                   NaN        NaN     NaN             NaN
# 26             iPhone 6S        Bom    16GB  Cinza espacial
# 27             iPhone 6S  Excelente    16GB  Cinza espacial
# 28             iPhone 6S  Muito Bom    16GB  Cinza espacial
# 29             iPhone 6S        Bom    16GB  Cinza espacial
# 30             iPhone 6S  Muito Bom    16GB  Cinza espacial
# 31             iPhone 6S  Muito Bom    32GB  Cinza espacial
# 32             iPhone 6S  Muito Bom    16GB  Cinza espacial
# 33             iPhone 6S        Bom    16GB  Cinza espacial
# 34             iPhone 6S  Muito Bom    16GB  Cinza espacial
# 35             iPhone 6S  Excelente    16GB  Cinza espacial
# 36             iPhone 6S        Bom    16GB  Cinza espacial
# 37             iPhone 6S  Muito Bom    16GB  Cinza espacial
# 38             iPhone 6S  Muito Bom    16GB       Ouro Rosa
# 39             iPhone 6S  Muito Bom    64GB       Ouro Rosa
# 40             iPhone 6S  Muito Bom    64GB         Dourado
# 41             iPhone 6S  Muito Bom    64GB  Cinza espacial
# 42                   NaN        NaN     NaN             NaN
# 43  Motorola Moto Z Play        Bom    32GB           Preto
# 44  Motorola Moto Z Play        Bom    32GB           Preto
#
#                                                  skus       ...        \
# 8   10310,13333,13347,9902,9944,12774,12801,12744,...       ...
# 9                                                 NaN       ...
# 10                                                NaN       ...
# 11                                                NaN       ...
# 12  5075,12536,12520,12661,12506,12549,10449,9175,...       ...
# 13                                                NaN       ...
# 14  5075,12536,12520,12661,12506,12549,10449,9175,...       ...
# 15                                                NaN       ...
# 16                                                NaN       ...
# 17                                                NaN       ...
# 18  6649,7237,2820,2750,6707,6720,7224,12619,12605...       ...
# 19  6649,7237,2820,2750,6707,6720,7224,12619,12605...       ...
# 20                                8499,8485,8471,8443       ...
# 21  6649,7237,2820,2750,6707,6720,7224,12619,12605...       ...
# 22                                                NaN       ...
# 23  6649,7237,2820,2750,6707,6720,7224,12619,12605...       ...
# 24  2694,2711,6011,5904,6931,2830,6023,10294,3647,...       ...
# 25  6931,6888,6847,6957,6902,6832,6581,6875,8965,8...       ...
# 26                                                NaN       ...
# 27                                                NaN       ...
# 28                                                NaN       ...
# 29                                                NaN       ...
# 30                                                NaN       ...
# 31                                                NaN       ...
# 32                                                NaN       ...
# 33                                                NaN       ...
# 34                                                NaN       ...
# 35                                                NaN       ...
# 36                                                NaN       ...
# 37                                                NaN       ...
# 38                                                NaN       ...
# 39                                                NaN       ...
# 40                                                NaN       ...
# 41                                                NaN       ...
# 42  4956,9174,7616,3107,5016,8429,9217,10448,4968,...       ...
# 43                                                NaN       ...
# 44                                                NaN       ...
#
#    search_engine channel new_vs_returning            city          region  \
# 8            NaN     NaN              NaN             NaN             NaN
# 9            NaN    Paid              New  Rio de Janeiro  Rio de Janeiro
# 10        Google     NaN              NaN             NaN             NaN
# 11           NaN     NaN              NaN             NaN             NaN
# 12           NaN     NaN              NaN             NaN             NaN
# 13           NaN     NaN              NaN             NaN             NaN
# 14           NaN     NaN              NaN             NaN             NaN
# 15           NaN     NaN              NaN             NaN             NaN
# 16           NaN    Paid        Returning  Rio de Janeiro  Rio de Janeiro
# 17        Google     NaN              NaN             NaN             NaN
# 18           NaN     NaN              NaN             NaN             NaN
# 19           NaN     NaN              NaN             NaN             NaN
# 20           NaN     NaN              NaN             NaN             NaN
# 21           NaN     NaN              NaN             NaN             NaN
# 22           NaN     NaN              NaN             NaN             NaN
# 23           NaN     NaN              NaN             NaN             NaN
# 24           NaN     NaN              NaN             NaN             NaN
# 25           NaN     NaN              NaN             NaN             NaN
# 26           NaN     NaN              NaN             NaN             NaN
# 27           NaN     NaN              NaN             NaN             NaN
# 28           NaN     NaN              NaN             NaN             NaN
# 29           NaN     NaN              NaN             NaN             NaN
# 30           NaN     NaN              NaN             NaN             NaN
# 31           NaN     NaN              NaN             NaN             NaN
# 32           NaN     NaN              NaN             NaN             NaN
# 33           NaN     NaN              NaN             NaN             NaN
# 34           NaN     NaN              NaN             NaN             NaN
# 35           NaN     NaN              NaN             NaN             NaN
# 36           NaN     NaN              NaN             NaN             NaN
# 37           NaN     NaN              NaN             NaN             NaN
# 38           NaN     NaN              NaN             NaN             NaN
# 39           NaN     NaN              NaN             NaN             NaN
# 40           NaN     NaN              NaN             NaN             NaN
# 41           NaN     NaN              NaN             NaN             NaN
# 42           NaN     NaN              NaN             NaN             NaN
# 43           NaN     NaN              NaN             NaN             NaN
# 44           NaN     NaN              NaN             NaN             NaN
#
#    country device_type screen_resolution operating_system_version  \
# 8      NaN         NaN               NaN                      NaN
# 9   Brazil    Computer         1920x1080              Windows 10
# 10     NaN         NaN               NaN                      NaN
# 11     NaN         NaN               NaN                      NaN
# 12     NaN         NaN               NaN                      NaN
# 13     NaN         NaN               NaN                      NaN
# 14     NaN         NaN               NaN                      NaN
# 15     NaN         NaN               NaN                      NaN
# 16  Brazil    Computer         1920x1080              Windows 10
# 17     NaN         NaN               NaN                      NaN
# 18     NaN         NaN               NaN                      NaN
# 19     NaN         NaN               NaN                      NaN
# 20     NaN         NaN               NaN                      NaN
# 21     NaN         NaN               NaN                      NaN
# 22     NaN         NaN               NaN                      NaN
# 23     NaN         NaN               NaN                      NaN
# 24     NaN         NaN               NaN                      NaN
# 25     NaN         NaN               NaN                      NaN
# 26     NaN         NaN               NaN                      NaN
# 27     NaN         NaN               NaN                      NaN
# 28     NaN         NaN               NaN                      NaN
# 29     NaN         NaN               NaN                      NaN
# 30     NaN         NaN               NaN                      NaN
# 31     NaN         NaN               NaN                      NaN
# 32     NaN         NaN               NaN                      NaN
# 33     NaN         NaN               NaN                      NaN
# 34     NaN         NaN               NaN                      NaN
# 35     NaN         NaN               NaN                      NaN
# 36     NaN         NaN               NaN                      NaN
# 37     NaN         NaN               NaN                      NaN
# 38     NaN         NaN               NaN                      NaN
# 39     NaN         NaN               NaN                      NaN
# 40     NaN         NaN               NaN                      NaN
# 41     NaN         NaN               NaN                      NaN
# 42     NaN         NaN               NaN                      NaN
# 43     NaN         NaN               NaN                      NaN
# 44     NaN         NaN               NaN                      NaN
#
#    browser_version
# 8              NaN
# 9      Chrome 65.0
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16     Chrome 66.0
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# 30             NaN
# 31             NaN
# 32             NaN
# 33             NaN
# 34             NaN
# 35             NaN
# 36             NaN
# 37             NaN
# 38             NaN
# 39             NaN
# 40             NaN
# 41             NaN
# 42             NaN
# 43             NaN
# 44             NaN
#
# [37 rows x 23 columns]

# %% [markdown]
# ## Analyse of the lead

# %%
df_lead = df[df['event'] == 'lead']

# %%
df_lead.groupby('model').count().sort_values(by ='timestamp', ascending=False)
# Out:
#                                      timestamp  event  person  url  sku  \
# model
# iPhone 6 Plus                               35     35      35    0    0
# iPhone 6S Plus                              31     31      31    0    0
# Samsung Galaxy J7 Prime                     26     26      26    0    0
# iPhone 6S                                   21     21      21    0    0
# iPhone 8                                    20     20      20    0    0
# Motorola Moto G4 Plus                       20     20      20    0    0
# Samsung Galaxy On 7                         15     15      15    0    0
# Motorola Moto G5 Plus                       15     15      15    0    0
# Samsung Galaxy A9 Pro 2016                  15     15      15    0    0
# LG K10 Novo                                 12     12      12    0    0
# iPhone 6                                    12     12      12    0    0
# Motorola Moto G5S Plus                       9      9       9    0    0
# iPhone 7 Plus                                9      9       9    0    0
# Samsung Galaxy J7 PRO                        8      8       8    0    0
# Lenovo Vibe A7010 Dual Chip                  7      7       7    0    0
# iPhone 8 Plus                                7      7       7    0    0
# LG K10 TV                                    6      6       6    0    0
# Samsung Galaxy Note 5                        5      5       5    0    0
# LG X Power                                   5      5       5    0    0
# Motorola Moto G2 3G Dual                     5      5       5    0    0
# iPhone 5s                                    5      5       5    0    0
# LG K4                                        5      5       5    0    0
# Motorola Moto G4 Play DTV                    5      5       5    0    0
# iPhone 7                                     5      5       5    0    0
# iPhone SE                                    5      5       5    0    0
# Samsung Galaxy J5 Prime                      4      4       4    0    0
# Motorola Moto Z2 Play                        4      4       4    0    0
# Motorola Moto Z2 Force                       4      4       4    0    0
# iPhone X                                     4      4       4    0    0
# iPhone 5c                                    4      4       4    0    0
# ...                                        ...    ...     ...  ...  ...
# Motorola Moto Z Play                         2      2       2    0    0
# Samsung Galaxy Core Plus Duos TV             2      2       2    0    0
# Samsung Galaxy A7 2016                       1      1       1    0    0
# Samsung Galaxy Gran Prime Duos TV            1      1       1    0    0
# Samsung Galaxy Gran 2 Duos TV                1      1       1    0    0
# Motorola Moto G1 3G                          1      1       1    0    0
# Motorola Moto G1 3G                          0        0      0     0
# LG G4 H815P                                  0        0      0     0
# Blackberry Blackberry Z30                    0        0      0     0
# LG G3 Stylus D690                            0        0      0     0
# LG  X Screen                                 0        0      0     0
# Samsung Galaxy J3                            0        0      0     0
# iPad Mini Wi-Fi + 4G                         0        0      0     0
# Samsung Galaxy A7                            0        0      0     0
# Samsung Galaxy Note 4                        0        0      0     0
# Sony Xperia M4 Aqua                          0        0      0     0
# Samsung Galaxy J5 2016 Metal                 0        0      0     0
# Samsung Galaxy Win 2 Duos TV                 0        0      0     0
# Samsung Galaxy Tab E 9.6 Wi-Fi + 3G          0        0      0     0
# Quantum GO 3G                                0        0      0     0
# Samsung Galaxy J7 2016 Metal                 0        0      0     0
# Motorola Moto MAXX                           0        0      0     0
# Samsung Galaxy S6 Flat                       0        0      0     0
# Samsung Galaxy Core 2 Duos                   0        0      0     0
# Samsung Galaxy S5 Mini Duos                  0        0      0     0
# Samsung Galaxy S3 Slim Duos                  0        0      0     0
# Samsung Galaxy S3 Mini                       0        0      0     0
# Motorola Moto X Play 4G Dual                 0        0      0     0
# Samsung Galaxy Note Edge                     0        0      0     0
# Motorola RAZR I                              0        0      0     0
# Sony Xperia Z3 TV                            0        0      0     0
#
#                                      search_term       ...         \
# model                                                  ...
# iPhone 6 Plus                                  0       ...
# iPhone 6S Plus                                 0       ...
# Samsung Galaxy J7 Prime                        0       ...
# iPhone 6S                                      0       ...
# iPhone 8                                       0       ...
# Motorola Moto G4 Plus                          0       ...
# Samsung Galaxy On 7                            0       ...
# Motorola Moto G5 Plus                          0       ...
# Samsung Galaxy A9 Pro 2016                     0       ...
# LG K10 Novo                                    0       ...
# iPhone 6                                       0       ...
# Motorola Moto G5S Plus                         0       ...
# iPhone 7 Plus                                  0       ...
# Samsung Galaxy J7 PRO                          0       ...
# Lenovo Vibe A7010 Dual Chip                    0       ...
# iPhone 8 Plus                                  0       ...
# LG K10 TV                                      0       ...
# Samsung Galaxy Note 5                          0       ...
# LG X Power                                     0       ...
# Motorola Moto G2 3G Dual                       0       ...
# iPhone 5s                                      0       ...
# LG K4                                          0       ...
# Motorola Moto G4 Play DTV                      0       ...
# iPhone 7                                       0       ...
# iPhone SE                                      0       ...
# Samsung Galaxy J5 Prime                        0       ...
# Motorola Moto Z2 Play                          0       ...
# Motorola Moto Z2 Force                         0       ...
# iPhone X                                       0       ...
# iPhone 5c                                      0       ...
# ...                                          ...       ...
# Motorola Moto Z Play                           0       ...
# Samsung Galaxy Core Plus Duos TV               0       ...
# Samsung Galaxy A7 2016                         0       ...
# Samsung Galaxy Gran Prime Duos TV              0       ...
# Samsung Galaxy Gran 2 Duos TV                  0       ...
# Motorola Moto G1 3G                            0       ...
# LG G4 H815P                                    0       ...
# Blackberry Blackberry Z30                      0       ...
# LG G3 Stylus D690                              0       ...
# LG  X Screen                                   0       ...
# Samsung Galaxy J3                              0       ...
# iPad Mini Wi-Fi + 4G                           0       ...
# Samsung Galaxy A7                              0       ...
# Samsung Galaxy On 7                                         0                0
# Motorola Moto G5 Plus                                       0                0
# Samsung Galaxy A9 Pro 2016                                  0                0
# LG K10 Novo                                                 0                0
# iPhone 6                                                    0                0
# Motorola Moto G5S Plus                                      0                0
# iPhone 7 Plus                                               0                0
# Samsung Galaxy J7 PRO                                       0                0
# Lenovo Vibe A7010 Dual Chip                                 0                0
# iPhone 8 Plus                                               0                0
# LG K10 TV                                                   0                0
# Samsung Galaxy Note 5                                       0                0
# LG X Power                                                  0                0
# Motorola Moto G2 3G Dual                                    0                0
# iPhone 5s                                                   0                0
# LG K4                                                       0                0
# Motorola Moto G4 Play DTV                                   0                0
# iPhone 7                                                    0                0
# iPhone SE                                                   0                0
# Samsung Galaxy J5 Prime                                     0                0
# Motorola Moto Z2 Play                                       0                0
# Motorola Moto Z2 Force                                      0                0
# iPhone X                                                    0                0
# iPhone 5c                                                   0                0
# ...                                                       ...              ...
# Motorola Moto Z Play                                        0                0
# Samsung Galaxy Core Plus Duos TV                            0                0
# Samsung Galaxy A7 2016                                      0                0
# Samsung Galaxy Gran Prime Duos TV                           0                0
# Samsung Galaxy Gran 2 Duos TV                               0                0
# Motorola Moto G1 3G                                         0                0
# LG G4 H815P                                                 0                0
# Blackberry Blackberry Z30                                   0                0
# LG G3 Stylus D690                                           0                0
# LG  X Screen                                                0                0
# Samsung Galaxy J3                                           0                0
# iPad Mini Wi-Fi + 4G                                        0                0
# Samsung Galaxy A7                                           0                0
# Samsung Galaxy Note 4                                       0                0
# Sony Xperia M4 Aqua                                         0                0
# Samsung Galaxy J5 2016 Metal                                0                0
# Samsung Galaxy Win 2 Duos TV                                0                0
# Samsung Galaxy Tab E 9.6 Wi-Fi + 3G                         0                0
# Quantum GO 3G                                               0                0
# Samsung Galaxy J7 2016 Metal                                0                0
# Motorola Moto MAXX                                          0                0
# Samsung Galaxy S6 Flat                                      0                0
# Samsung Galaxy Core 2 Duos                                  0                0
# Samsung Galaxy S5 Mini Duos                                 0                0
# Samsung Galaxy S3 Slim Duos                                 0                0
# Samsung Galaxy S3 Mini                                      0                0
# Motorola Moto X Play 4G Dual                                0                0
# Samsung Galaxy Note Edge                                    0                0
# Motorola RAZR I                                             0                0
# Sony Xperia Z3 TV                                           0                0
#
# [95 rows x 22 columns]

# %%
#model is a string
def lead_over_conversion(model1):
    number_sold3 = df_conversion['timestamp'][df_conversion['model'] == model1 ].count()
    number_lead3 = df_lead['timestamp'][df_lead['model'] == model1 ].count()
    if number_sold3 != 0:
        return [model1, number_lead3, number_lead3/number_sold3]  ### the 1 is for indicating that number_sold3 is different from 0
    else:
        return [model1, number_lead3, -1] ### the 0 is for indicating that number_sold3 is equal to 0

# %%
lead_over_conversion("iPhone 6 Plus")
# Out:
# ['iPhone 6 Plus', 35, 4.375]

# %%
df_lead['timestamp'][df_lead['model'] == 'iPhone 6S Plus' ].count()
# Out:
# 31

# %%
df_lead_model = df_lead['model'].unique().tolist()

# %%
type(df_lead_model)
# Out:
# list

# %%
lead_over_conversion_list = []
lead_only = []
for model_phone in df_lead_model:
    lead_only.append(lead_over_conversion(model_phone)[0:2])
    if lead_over_conversion(model_phone)[2] != -1:
        lead_over_conversion_list.append(lead_over_conversion(model_phone))
        
        
lead_over_conversion_list.sort(key=lambda x: x[2], reverse=True)
lead_only.sort(key = lambda x: x[1], reverse=True)
print(lead_over_conversion_list)
print(lead_only)
# Out:
# [['iPhone 8', 20, 20.0], ['Samsung Galaxy A9 Pro 2016', 15, 15.0], ['Motorola Moto G5S Plus', 9, 9.0], ['Samsung Galaxy On 7', 15, 7.5], ['LG K10 Novo', 12, 6.0], ['Motorola Moto G5 Plus', 15, 5.0], ['iPhone 6 Plus', 35, 4.375], ['Motorola Moto Z2 Play', 4, 4.0], ['Samsung Galaxy J5 PRO', 3, 3.0], ['Asus Zenfone 3 Max 16 GB', 3, 3.0], ['iPhone 6S Plus', 31, 2.2142857142857144], ['LG K10 TV', 6, 2.0], ['Motorola Moto X Force', 2, 2.0], ['LG G4 H818P', 2, 2.0], ['Lenovo Vibe A7010 Dual Chip', 7, 1.75], ['Motorola Moto Z', 3, 1.5], ['iPhone 7 Plus', 9, 1.5], ['LG K10', 4, 1.3333333333333333], ['Samsung Galaxy J7 Prime', 26, 1.3], ['Samsung Galaxy Note 5', 5, 1.0], ['Sony Xperia M4 Aqua', 1, 1.0], ['Motorola Moto G4 Play DTV', 5, 0.7142857142857143], ['Samsung Galaxy J2 4G Duos TV', 2, 0.6666666666666666], ['Samsung Galaxy Core Plus Duos TV', 2, 0.6666666666666666], ['Samsung Galaxy Note 8', 2, 0.6666666666666666], ['Motorola Moto G4 Plus', 20, 0.6666666666666666], ['Samsung Galaxy Y Duos', 2, 0.6666666666666666], ['Motorola Moto Z Play', 2, 0.6666666666666666], ['Motorola Moto G4 Play', 3, 0.6], ['Samsung Galaxy J5 Prime', 4, 0.5714285714285714], ['iPhone 6S', 21, 0.5675675675675675], ['LG G4 H815P', 1, 0.5], ['Samsung Galaxy Win 2 Duos TV', 1, 0.5], ['iPhone 4G', 3, 0.3333333333333333], ['Samsung Galaxy J3', 1, 0.3333333333333333], ['Samsung Galaxy J1 2016', 2, 0.3333333333333333], ['Samsung Galaxy A7 2017', 2, 0.3333333333333333], ['iPhone 7', 5, 0.3125], ['Lenovo Vibe K5', 3, 0.3], ['iPhone SE', 5, 0.29411764705882354], ['Motorola Moto G2 3G Dual', 5, 0.29411764705882354], ['Motorola Moto G5 ', 2, 0.2857142857142857], ['Samsung Galaxy S8 Plus', 2, 0.2857142857142857], ['Samsung Galaxy A7', 1, 0.25], ['Sony Xperia Z3 TV', 1, 0.25], ['Motorola Moto MAXX ', 1, 0.25], ['Samsung Galaxy Grand Duos i9082', 3, 0.25], ['Samsung Galaxy S7 Edge', 4, 0.23529411764705882], ['iPhone 4S', 2, 0.2], ['Samsung Galaxy S6 Edge', 3, 0.1875], ['iPhone 5', 3, 0.17647058823529413], ['iPhone 6', 12
TV', 2], ['LG Prime Plus H522', 2], ['iPhone 4S', 2], ['Motorola Moto X Force', 2], ['Samsung Galaxy S8 Plus', 2], ['Samsung Galaxy Note 8', 2], ['Samsung Galaxy J7', 2], ['Samsung Galaxy A7 2017', 2], ['LG G5 SE', 2], ['Samsung Galaxy Y Duos', 2], ['LG G4 H818P', 2], ['Samsung Galaxy J2 4G Duos ', 2], ['Samsung Galaxy Tab E 9.6 Wi-Fi', 2], ['Motorola Moto Z Play', 2], ['Samsung Galaxy J2 Prime TV', 2], ['iPad Mini Wi-Fi + 4G', 1], ['Samsung Galaxy S5 Mini Duos', 1], ['Samsung Galaxy S3 Slim Duos', 1], ['Sony Xperia M4 Aqua', 1], ['LG G4 H815P', 1], ['Samsung Galaxy J3', 1], ['Samsung Galaxy A7', 1], ['Sony Xperia Z3 TV', 1], ['LG G3 Stylus D690', 1], ['Samsung Galaxy Gran Prime Duos TV', 1], ['Motorola Moto X Play 4G Dual', 1], ['Samsung Galaxy A7 2016', 1], ['Samsung Galaxy Core 2 Duos', 1], ['Motorola RAZR I', 1], ['Motorola Moto G1 3G', 1], ['Samsung Galaxy Note 4', 1], ['Samsung Galaxy S6 Flat', 1], ['Samsung Galaxy Tab E 9.6 Wi-Fi + 3G', 1], ['Quantum GO 3G', 1], ['Motorola Moto MAXX ', 1], ['Samsung Galaxy Note Edge', 1], ['Samsung Galaxy J5 2016 Metal', 1], ['Samsung Galaxy Gran 2 Duos TV', 1], ['Samsung Galaxy S3 Mini', 1], ['Samsung Galaxy J7 2016 Metal', 1], ['Blackberry Blackberry Z30', 1], ['Samsung Galaxy Win 2 Duos TV', 1], ['LG  X Screen', 1]]

# %% [markdown]
# <div class = 'alert alert-info'> Maybe try to analyze the lead regarding the time, maybe there was one month that has all the delay <div>

# %%
lead_over_conversion_list_over5 = []
for i in range(len(lead_over_conversion_list)):
               if lead_over_conversion_list[i][2] >= 5:
                   lead_over_conversion_list_top5.append(lead_over_conversion_list[i])
lead_over_conversion_list_over5.sort(key=lambda x: x[2], reverse=True)
X = [lead_over_conversion_list_top5[i][0] for i in range(len(lead_over_conversion_list_top5))]
Y = [lead_over_conversion_list_top5[i][2] for i in range(len(lead_over_conversion_list_top5))]

plt.bar(X, Y)
plt.title('Lead over conversion rate regarding the model of the phone if the rate is over 500%')
plt.xlabel('Model of the smartphone')
plt.ylabel('Lead over conversion rate')
plt.gcf().set_size_inches(18.5, 10.5)
plt.show()

# %%
lead_only_over10 = []
for i in range(len(lead_only)):
               if lead_only[i][1] >= 16:
                   lead_only_over10.append(lead_only[i])
lead_only_over10.sort(key=lambda x: x[1], reverse=True)

X = [lead_only_over10[i][0] for i in range(len(lead_only_over10))]
Y = [lead_only_over10[i][1] for i in range(len(lead_only_over10))]

plt.bar(X, Y)
plt.title('Number of lead regarding the model of the phone if the number is above 16')
plt.xlabel('Model of the smartphone')
plt.ylabel('Number of leads')
plt.gcf().set_size_inches(18.5, 10.5)
plt.show()
